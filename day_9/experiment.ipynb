# %%
with open('input.txt') as file:
    data = file.read().splitlines()

# %%
data
# Out:
# ['D 2',
#  'U 2',
#  'L 2',
#  'D 2',
#  'L 2',
#  'D 2',
#  'L 1',
#  'D 2',
#  'U 1',
#  'L 1',
#  'D 1',
#  'R 1',
#  'D 1',
#  'L 2',
#  'D 1',
#  'U 2',
#  'D 2',
#  'R 2',
#  'D 1',
#  'U 2',
#  'L 2',
#  'D 1',
#  'R 1',
#  'D 1',
#  'R 2',
#  'U 2',
#  'L 2',
#  'U 2',
#  'D 1',
#  'U 2',
#  'R 2',
#  'L 2',
#  'R 2',
#  'D 2',
#  'L 1',
#  'R 2',
#  'D 2',
#  'R 2',
#  'D 1',
#  'R 2',
#  'D 2',
#  'R 2',
#  'L 1',
#  'R 1',
#  'U 2',
#  'D 2',
#  'R 2',
#  'D 1',
#  'L 2',
#  'D 1',
#  'L 1',
#  'U 2',
#  'L 1',
#  'U 2',
#  'R 2',
#  'D 1',
#  'L 1',
#  'D 2',
#  'L 1',
#  'D 1',
#  'R 1',
#  'D 2',
#  'R 2',
#  'D 2',
#  'L 2',
#  'D 2',
#  'U 2',
#  'L 1',
#  'R 2',
#  'L 1',
#  'D 2',
#  'L 2',
#  'D 2',
#  'U 2',
#  'L 1',
#  'R 2',
#  'U 2',
#  'D 2',
#  'R 1',
#  'L 2',
#  'D 1',
#  'R 2',
#  'D 2',
#  'L 1',
#  'R 1',
#  'L 2',
#  'D 1',
#  'R 1',
#  'D 1',
#  'L 1',
#  'U 2',
#  'R 1',
#  'U 1',
#  'L 1',
#  'U 1',
#  'L 2',
#  'U 2',
#  'L 2',
#  'U 2',
#  'R 1',
# ...
